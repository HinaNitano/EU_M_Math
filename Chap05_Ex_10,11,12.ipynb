# %% [markdown]
# <a href="https://colab.research.google.com/github/HinaNitano/EU_M_Math/blob/main/Chap05_Ex_10%2C11%2C12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
x = np.linspace(0, 10, num=11, endpoint=True)
y = np.sin(x**2/5.0)
plt.plot(x,y,'o')
plt.grid(True)

# %%
from scipy import interpolate

f = interpolate.interp1d(x, y,'linear')
plt.plot(x,y,'o',x,f(x),'-',)
plt.legend(['data', 'quadratic'], loc='best')
plt.grid(True)

# %%
f2 = interpolate.interp1d(x,y,'cubic')

xnew = np.linspace(0,10,num=30,endpoint=True)

plt.plot(x,y,'o',x,f(x),'-',xnew,f2(xnew),'--')
plt.legend(['data', 'linear', 'cubic'], loc='best')
plt.grid(True)
