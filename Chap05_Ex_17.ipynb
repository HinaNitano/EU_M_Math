# %% [markdown]
# <a href="https://colab.research.google.com/github/HinaNitano/EU_M_Math/blob/main/Chap05_Ex_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
from scipy.optimize import fsolve

# %%
def f(x):
  y = 5 * x - 10
  return y

# %%
x = np.linspace(-4, 4)
plt.plot(x, f(x))
plt.plot(x, np.zeros(len(x)))
plt.grid(True)

# %%
x = fsolve(f, 0)
print(x)
# Out:
# [2.]
